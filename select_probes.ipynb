# %%
import pandas as pd 

df = pd.read_csv('probe_counts_out/part-00000-97859fdb-2133-44ae-9006-7a81cec65b97-c000.csv')

# %%
df.head()
# Out:
#   chromosome probe_id_id  n_patients_with_probe
# 0      chr11  cg00080012                  10979
# 1      chr11  cg00146096                  10979
# 2      chr11  cg00554702                  10978
# 3      chr11  cg00858899                  10973
# 4      chr11  cg00901652                  10978

# %%
df.describe()

# %%
import plotly.express as px

px.box(df, x='chromosome', y='n_patients_with_probe', color='probe_id_id')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24887/749526377.py in <module>
#       1 import plotly.express as px
#       2
# ----> 3 px.box(df, x='chromosome', y='n_patients_with_probe', color='probe_id_id')
#
# ~/.local/lib/python3.10/site-packages/plotly/express/_chart_types.py in box(data_frame, x, y, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, orientation, boxmode, log_x, log_y, range_x, range_y, points, notched, title, subtitle, template, width, height)
#     677     range (IQR: Q3-Q1), see "points" for other options.
#     678     """
# --> 679     return make_figure(
#     680         args=locals(),
#     681         constructor=go.Box,
#
# ...
